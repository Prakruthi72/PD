# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakruthi72/PD/blob/main/Titanic_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-9c69164e-5b7d-480d-8bb7-570138d1ab76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c69164e-5b7d-480d-8bb7-570138d1ab76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Titanic_data = pd.read_csv('Titanic.csv')

# %%
Titanic_data.head()
# Out:
#   Class Gender    Age Survived
# 0   3rd   Male  Child       No
# 1   3rd   Male  Child       No
# 2   3rd   Male  Child       No
# 3   3rd   Male  Child       No
# 4   3rd   Male  Child       No

# %%
Titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Class     2201 non-null   object
#  1   Gender    2201 non-null   object
#  2   Age       2201 non-null   object
#  3   Survived  2201 non-null   object
# dtypes: object(4)
# memory usage: 68.9+ KB

# %%
Titanic_data.duplicated()
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2196     True
# 2197     True
# 2198     True
# 2199     True
# 2200     True
# Length: 2201, dtype: bool

# %%
Titanic_data.duplicated().sum()
# Out:
# 2177

# %%
Titanic_data.drop_duplicates()
# Out:
#      Class  Gender    Age Survived
# 0      3rd    Male  Child       No
# 35     3rd  Female  Child       No
# 52     1st    Male  Adult       No
# 170    2nd    Male  Adult       No
# 324    3rd    Male  Adult       No
# 711   Crew    Male  Adult       No
# 1381   1st  Female  Adult       No
# 1385   2nd  Female  Adult       No
# 1398   3rd  Female  Adult       No
# 1487  Crew  Female  Adult       No
# 1490   1st    Male  Child      Yes
# 1495   2nd    Male  Child      Yes
# 1506   3rd    Male  Child      Yes
# 1519   1st  Female  Child      Yes
# 1520   2nd  Female  Child      Yes
# 1533   3rd  Female  Child      Yes
# 1547   1st    Male  Adult      Yes
# 1604   2nd    Male  Adult      Yes
# 1618   3rd    Male  Adult      Yes
# 1693  Crew    Male  Adult      Yes
# 1885   1st  Female  Adult      Yes
# 2025   2nd  Female  Adult      Yes
# 2105   3rd  Female  Adult      Yes
# 2181  Crew  Female  Adult      Yes

# %%
data = Titanic_data.drop_duplicates()

# %%
data.shape
# Out:
# (24, 4)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data2 = pd.get_dummies(data, columns = ['Class','Gender','Age'])

# %%
data2
# Out:
#      Survived  Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  \
# 0          No          0          0          1           0              0
# 35         No          0          0          1           0              1
# 52         No          1          0          0           0              0
# 170        No          0          1          0           0              0
# 324        No          0          0          1           0              0
# 711        No          0          0          0           1              0
# 1381       No          1          0          0           0              1
# 1385       No          0          1          0           0              1
# 1398       No          0          0          1           0              1
# 1487       No          0          0          0           1              1
# 1490      Yes          1          0          0           0              0
# 1495      Yes          0          1          0           0              0
# ...

# %%
data2.shape
# Out:
# (24, 9)

# %%
from sklearn.linear_model import LogisticRegression

# %%
data3 = data2['Survived'].map({'Yes': 1, 'No': 0})

# %%
data3
# Out:
# 0       0
# 35      0
# 52      0
# 170     0
# 324     0
# 711     0
# 1381    0
# 1385    0
# 1398    0
# 1487    0
# 1490    1
# 1495    1
# 1506    1
# 1519    1
# 1520    1
# 1533    1
# 1547    1
# 1604    1
# 1618    1
# 1693    1
# 1885    1
# 2025    1
# 2105    1
# 2181    1
# Name: Survived, dtype: int64

# %%
final_data = pd.concat([data2,data3],axis =1)

# %%
final_data
# Out:
#       Survived  Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  \
# 0           No          0          0          1           0              0
# 35          No          0          0          1           0              1
# 52          No          1          0          0           0              0
# 170         No          0          1          0           0              0
# 324         No          0          0          1           0              0
# 711         No          0          0          0           1              0
# 1381        No          1          0          0           0              1
# 1385        No          0          1          0           0              1
# 1398        No          0          0          1           0              1
# 1487        No          0          0          0           1              1
# 1490       Yes          1          0          0           0              0
# ...

# %%
final_data.columns = ['Survived1','Class_1st',	'Class_2nd',	'Class_3rd',	'Class_Crew',	'Gender_Female',	'Gender_Male','Age_Adult',	'Age_Child',	'Survived']

# %%
final_data
# Out:
#      Survived1  Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  \
# 0           No          0          0          1           0              0
# 35          No          0          0          1           0              1
# 52          No          1          0          0           0              0
# 170         No          0          1          0           0              0
# 324         No          0          0          1           0              0
# 711         No          0          0          0           1              0
# 1381        No          1          0          0           0              1
# 1385        No          0          1          0           0              1
# 1398        No          0          0          1           0              1
# 1487        No          0          0          0           1              1
# 1490       Yes          1          0          0           0              0
# ...

# %%
final_data.drop(['Survived1'],inplace = True,axis=1)

# %%
final_data.head()
# Out:
#      Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  Gender_Male  \
# 0            0          0          1           0              0            1
# 35           0          0          1           0              1            0
# 52           1          0          0           0              0            1
# 170          0          1          0           0              0            1
# 324          0          0          1           0              0            1
#
#      Age_Adult  Age_Child  Survived
# 0            0          1         0
# 35           0          1         0
# 52           1          0         0
# 170          1          0         0
# 324          1          0         0

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 2181
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Class_1st      24 non-null     uint8
#  1   Class_2nd      24 non-null     uint8
#  2   Class_3rd      24 non-null     uint8
#  3   Class_Crew     24 non-null     uint8
#  4   Gender_Female  24 non-null     uint8
#  5   Gender_Male    24 non-null     uint8
#  6   Age_Adult      24 non-null     uint8
#  7   Age_Child      24 non-null     uint8
#  8   Survived       24 non-null     int64
# dtypes: int64(1), uint8(8)
# memory usage: 576.0 bytes

# %%
X = final_data.iloc[:,0:8]
Y = final_data.iloc[:,8]

# %%
Y.head()
# Out:
# 0      0
# 35     0
# 52     0
# 170    0
# 324    0
# Name: Survived, dtype: int64

# %%
X.head()
# Out:
#      Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  Gender_Male  \
# 0            0          0          1           0              0            1
# 35           0          0          1           0              1            0
# 52           1          0          0           0              0            1
# 170          0          1          0           0              0            1
# 324          0          0          1           0              0            1
#
#      Age_Adult  Age_Child
# 0            0          1
# 35           0          1
# 52           1          0
# 170          1          0
# 324          1          0

# %%
#Logistic regression and fit the model
classifier = LogisticRegression()
classifier.fit(X,Y)
# Out:
# LogisticRegression()

# %%
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(classifier, open(filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-4a03dc7b3354> in <module>
#       1 # save the model to disk
#       2 filename = 'finalized_model.sav'
# ----> 3 pickle.dump(classifier, open(filename, 'wb'))
#
# NameError: name 'pickle' is not defined

# %%
#Predict for X dataset
# pickle.load(open(filename, 'rb'))
# classifier.read_pickle_file('/content/finalized_model.sav')
y_pred = classifier.predict(X)

# %%
y_pred_df = pd.DataFrame({'Actual':Y, 'Predicted': classifier.predict(X)})

# %%
y_pred_df
# Out:
#       Actual  Predicted
# 0          0          1
# 35         0          1
# 52         0          1
# 170        0          1
# 324        0          0
# 711        0          1
# 1381       0          1
# 1385       0          1
# 1398       0          0
# 1487       0          1
# 1490       1          1
# 1495       1          1
# 1506       1          1
# 1519       1          1
# 1520       1          1
# 1533       1          1
# 1547       1          1
# 1604       1          1
# 1618       1          0
# 1693       1          1
# 1885       1          1
# 2025       1          1
# 2105       1          0
# 2181       1          1

# %%
# Confusion metrics for model accuracy
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y,y_pred)
confusion_matrix
# Out:
# array([[ 2,  8],
#        [ 2, 12]])

# %%
# Classification report
## Precesion - What percent of your predictions were correct?
## Recall - What percent of the positive cases did you catch? 
## F1 score – What percent of positive predictions were correct?
from sklearn.metrics import classification_report
print(classification_report(Y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29        10
#            1       0.60      0.86      0.71        14
#
#     accuracy                           0.58        24
#    macro avg       0.55      0.53      0.50        24
# weighted avg       0.56      0.58      0.53        24

# %%
classifier.predict_proba(X)[:,1]
# Out:
# array([0.64292971, 0.64292971, 0.57412386, 0.57412386, 0.44162636,
#        0.51295748, 0.57412386, 0.57412386, 0.44162636, 0.51295748,
#        0.75424154, 0.75424154, 0.64292971, 0.75424154, 0.75424154,
#        0.64292971, 0.57412386, 0.57412386, 0.44162636, 0.51295748,
#        0.57412386, 0.57412386, 0.44162636, 0.51295748])

# %%
# ROC Curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(Y, classifier.predict_proba (X)[:,1])

auc = roc_auc_score(Y, y_pred)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
auc
# Out:
# 0.5285714285714286

# %%
import statsmodels.api as sm

# %%
X
# Out:
#       Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  Gender_Male  \
# 0             0          0          1           0              0            1
# 35            0          0          1           0              1            0
# 52            1          0          0           0              0            1
# 170           0          1          0           0              0            1
# 324           0          0          1           0              0            1
# 711           0          0          0           1              0            1
# 1381          1          0          0           0              1            0
# 1385          0          1          0           0              1            0
# 1398          0          0          1           0              1            0
# 1487          0          0          0           1              1            0
# 1490          1          0          0           0              0            1
# ...

# %%
sm.Logit(Y,X).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.629246
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                   24
# Model:                          Logit   Df Residuals:                       18
# Method:                           MLE   Df Model:                            5
# Date:                Sat, 07 Jan 2023   Pseudo R-squ.:                 0.07354
# Time:                        06:19:43   Log-Likelihood:                -15.102
# converged:                       True   LL-Null:                       -16.301
# Covariance Type:            nonrobust   LLR p-value:                    0.7918
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
